# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('~/Workshop/Sales-Analysis-Project/data/superstore_cleaned.csv')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 2          3  CA-2017-138688  2017-06-12  2017-06-16    Second Class
# 3          4  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# 4          5  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  2017-05-21  2017-05-28  Standard Class
# 9796    9797  CA-2016-128608  2016-01-12  2016-01-17  Standard Class
# 9797    9798  CA-2016-128608  2016-01-12  2016-01-17  Standard Class
# 9798    9799  CA-2016-128608  2016-01-12  2016-01-17  Standard Class
# 9799    9800  CA-2016-128608  2016-01-12  2016-01-17  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of seaborn
sns.set(style="whitegrid")
# Set the figure size
plt.figure(figsize=(12, 6))
# Create a bar plot
sns.barplot(x='Year', y='Sales', data=df, hue='Month', palette='viridis')
# Set the title and labels
plt.title('Sales by Year and Month')
plt.xlabel('Year')
plt.ylabel('Sales')
# Show the plot
plt.legend(title='Month', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Set the figure size for the second plot
plt.figure(figsize=(12, 6))
# Create a bar plot for regions
sns.barplot(x='Region', y='Sales', data=df, palette='viridis', hue='Segment')
# Set the title and labels
plt.title('Sales by Region and Segment')
plt.xlabel('Region')
plt.ylabel('Sales')
# Show the plot
plt.legend(title='Segment', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Set the figure size for the third plot
plt.figure(figsize=(12, 6))
# Create a bar plot for categories
sns.barplot(x='Sub-Category', y='Sales', data=df, palette='viridis', hue='Category')
# Set the title and labels
plt.title('Sales by Category and Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
# Rotate the x labels for better readability
plt.xticks(rotation=45)
# Show the plot
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Change datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
# Trend analysis
monthly_sales = df.set_index("Order Date").resample("ME")["Sales"].sum()
monthly_sales.plot(figsize=(12,5), title="Tren Bulanan Penjualan")
plt.ylabel("Total Sales")
plt.show()
